# %%
import tensorflow as tf
from tensorflow.keras import preprocessing 
from tensorflow.keras import layers
import numpy as np

# %%
samples = ['너 오늘 이뻐 보인다',
          '나는 오늘 기분이 더러워',
          '끝내주는데, 좋은 일이 있나봐',
          '나 좋은 일이 생겼어',
          '아 오늘 진짜 짜증나',
          '환상적인데, 정말 좋은거 같아']

targets = [[1], [0], [1], [1], [0], [1]]

# %%
tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(samples)

# %%
print(tokenizer.word_index)
# Out:
# {'오늘': 1, '좋은': 2, '일이': 3, '너': 4, '이뻐': 5, '보인다': 6, '나는': 7, '기분이': 8, '더러워': 9, '끝내주는데': 10, '있나봐': 11, '나': 12, '생겼어': 13, '아': 14, '진짜': 15, '짜증나': 16, '환상적인데': 17, '정말': 18, '좋은거': 19, '같아': 20}

# %%
sequences = tokenizer.texts_to_sequences(samples)
print(sequences)
# Out:
# [[4, 1, 5, 6], [7, 1, 8, 9], [10, 2, 3, 11], [12, 2, 3, 13], [14, 1, 15, 16], [17, 18, 19, 20]]

# %%
#넘파이 배열로 바꾸기 

input_sequences = np.array(sequences)
labels = np.array(targets)

# %%
word_index = tokenizer.word_index

# %%
print(input_sequences)
# Out:
# [[ 4  1  5  6]
#  [ 7  1  8  9]
#  [10  2  3 11]
#  [12  2  3 13]
#  [14  1 15 16]
#  [17 18 19 20]]

# %%
print(labels)
# Out:
# [[1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [1]]

# %%
batch_size = 2
num_epochs = 100
vocab_size = len(word_index) + 1 
#여기서 +1을 하는이유: 
emb_size = 128
hidden_dimension = 256
output_dimension = 1

# %%
model = tf.keras.Sequential()
model.add(layers.Embedding(vocab_size, emb_size, input_length=4))
model.add(layers.Lambda(lambda x: tf.reduce_mean(x, axis=1)))
#reduce mean : 특정축으로 평균값을 구함... 그렇게 하면 차원이 하나 줄어든다. 
#그래서 axis가 축을 의미하는데  1번축을 줄인다는것이다
model.add(layers.Dense(hidden_dimension, activation = 'relu'))
model.add(layers.Dense(output_dimension, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.001), 
              metrics = ['accuracy']  )

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 4, 128)            2688
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# ...
# Total params: 35,969
# Trainable params: 35,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# keras는 입력을 넘파이로 받아서 내부적으로 사용하는 tensor로 변환한다. 그래서 위에 보면 None이 하나의 차원을 의미한다. (또는 하나의 축, 0번축)
# (None, 4, 128)은 3차원(3축)이라는 것임

# %%
model.fit(input_sequences, labels, epochs = num_epochs, batch_size= batch_size)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5000
# Epoch 2/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6718 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6532 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6358 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6159 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5936 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5689 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 1.0000
# Epoch 10/100
# ...

# %%
class CustomModel(tf.keras.Model):
    def __init__(self, vocab_size, embed_dimension, hidden_dimension, output_dimension):
        super(CustomModel, self).__init__(name='my_model')
        self.embedding = layers.Embedding(vocab_size, embed_dimension)
        self.dense_layer = layers.Dense(hidden_dimension, activation='relu')
        self.output_layer = layers.Dense(output_dimension, activation = 'sigmoid')
    
    def call(self, inputs):
        x = self.embedding(inputs)
        x = tf.reduce_mean(x, axis=1)
        x = self.dense_layer(x)
        x = self.output_layer(x)
        
        return x

# %%
model = CustomModel(vocab_size = vocab_size,
                    embed_dimension = emb_size,
                    hidden_dimension = hidden_dimension,
                    output_dimension = output_dimension)

model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.001), 
              metrics = ['accuracy']  )

model.fit(input_sequences, labels, epochs = num_epochs, batch_size= batch_size)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 665us/step - loss: 0.6950 - accuracy: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 0s 997us/step - loss: 0.6772 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 665us/step - loss: 0.6591 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 997us/step - loss: 0.6417 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6236 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6010 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 998us/step - loss: 0.5765 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5441 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5089 - accuracy: 1.0000
# Epoch 10/100
# ...
