# %%
import os 
import pandas as pd 
import numpy as np

# %%
list1 = os.listdir()

# %%
list1
# Out:
# ['.ipynb_checkpoints',
#  '06.CNN.ipynb',
#  '06.CNN_donwload.ipynb',
#  '06.EDA.ipynb',
#  '06.EDA_download.ipynb',
#  '06.LSTM.ipynb',
#  '06.XGBoost.ipynb',
#  'data_in',
#  'data_out',
#  'Untitled.ipynb']

# %%
def directory_data(directory):
    data = {}
    data['review'] = []
    for file_path in os.listdir(directory):
        with open(os.path.join(directory, file_path), "r") as file:
