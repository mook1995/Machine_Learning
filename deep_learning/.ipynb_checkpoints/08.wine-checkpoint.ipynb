# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np 
import pandas as pd 
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
seed = 0 
np.random.seed(seed)
tf.random.set_seed(3)

# %%
df_pre = pd.read_csv('data/wine.csv')
df = df_pre.sample(frac=1)
#데이터중에 일부 샘플만 사용할 경우 판다스 데이터 프레임에서 
#sample()을 이용해서 50%의 데이터 샘플만 가져올수 있다.
#이렇게 하면 원래 데이터가 무작위로 섞여서 들어오기 떄문에 그에 따른 효과를 얻을 수 있다.

# %%
print(df.head())
# Out:
#       7.4   0.7     0   1.9  0.076    11     34   0.9978  3.51  0.56   9.4  5  \
# 5315  6.3  0.18  0.24   3.4  0.053  20.0  119.0  0.99373  3.11  0.52   9.2  6
# 2423  7.0  0.21  0.37   7.2  0.042  36.0  167.0  0.99580  3.26  0.56   9.8  6
# 3517  7.3  0.22  0.50  13.7  0.049  56.0  189.0  0.99940  3.24  0.66   9.0  6
# 1622  6.6  0.27  0.41   1.3  0.052  16.0  142.0  0.99510  3.42  0.47  10.0  6
# 4060  8.3  0.25  0.33   2.5  0.053  12.0   72.0  0.99404  2.89  0.48   9.5  5
#
#       1
# 5315  0
# 2423  0
# 3517  0
# 1622  0
# 4060  0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496 entries, 5315 to 2732
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   7.4     6496 non-null   float64
#  1   0.7     6496 non-null   float64
#  2   0       6496 non-null   float64
#  3   1.9     6496 non-null   float64
#  4   0.076   6496 non-null   float64
#  5   11      6496 non-null   float64
#  6   34      6496 non-null   float64
#  7   0.9978  6496 non-null   float64
#  8   3.51    6496 non-null   float64
#  9   0.56    6496 non-null   float64
#  10  9.4     6496 non-null   float64
#  11  5       6496 non-null   int64
#  12  1       6496 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.5 KB
# None

# %%
dataset = df.values
print(dataset.dtype)
#전체를 자동으로 float으로 바꾼것을 알수 있기 떄문에 astype을 안써줘도 된다.
# Out:
# float64

# %%
X = dataset[:,:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
#이진 분류이므로 sigmoid를 쓴다.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    #해당 폴더의 존재유무를 체크해준다. 

modelpath = './model/{epoch: 02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose=1,
                              save_best_only=True)
#학습을 진행하면서 말그대로 체크를 하는데, 체크해서 결과를 저장할 파일 패스를 넣어준거고, 저장하면서 
#val_loss값을 체크하고, verbose=1은 중간과정을 출력하도록한다.  
#여기서 val_loss는 하단 셀의 validation_split을 통해 나온 값을 말한다. 
#save_best_only=True는 모델이 향상될 때에만 저장을 하라는 옵션이다.

# %%
model.fit(X,Y, validation_split=0.2 ,epochs = 200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
#200개의 샘플단위로 백워트프로파게이션을 해서 bias와 가중치 파라메터를 업데이트 한다는 의미임 
#validation_split은 데이터셋80프로로 학습을 하면서 
#에포크가 돌때마다 20프로의 데이터로 검증을 하겠다는것이다.  
# print("Accuracy: %.4f" % (model.evaluate(X,Y)[1]))
# Out:
# Epoch 00001: saving model to ./model\ 1-0.3755.hdf5
#
# Epoch 00002: saving model to ./model\ 2-0.2767.hdf5
#
# Epoch 00003: saving model to ./model\ 3-0.2376.hdf5
#
# Epoch 00004: saving model to ./model\ 4-0.2289.hdf5
#
# Epoch 00005: saving model to ./model\ 5-0.2224.hdf5
#
# Epoch 00006: saving model to ./model\ 6-0.2150.hdf5
#
# Epoch 00007: saving model to ./model\ 7-0.2140.hdf5
#
# Epoch 00008: saving model to ./model\ 8-0.2042.hdf5
#
# Epoch 00009: saving model to ./model\ 9-0.1972.hdf5
#
# Epoch 00010: saving model to ./model\ 10-0.1933.hdf5
#
# Epoch 00011: saving model to ./model\ 11-0.1881.hdf5
#
# Epoch 00012: saving model to ./model\ 12-0.1889.hdf5
#
# Epoch 00013: saving model to ./model\ 13-0.1876.hdf5
#
# Epoch 00014: saving model to ./model\ 14-0.1785.hdf5
#
# Epoch 00015: saving model to ./model\ 15-0.1739.hdf5
#
# Epoch 00016: saving model to ./model\ 16-0.1734.hdf5
#
# Epoch 00017: saving model to ./model\ 17-0.1677.hdf5
#
# Epoch 00018: saving model to ./model\ 18-0.1738.hdf5
#
# Epoch 00019: saving model to ./model\ 19-0.1613.hdf5
#
# Epoch 00020: saving model to ./model\ 20-0.1603.hdf5
#
# Epoch 00021: saving model to ./model\ 21-0.1569.hdf5
#
# Epoch 00022: saving model to ./model\ 22-0.1528.hdf5
#
# Epoch 00023: saving model to ./model\ 23-0.1504.hdf5
#
# Epoch 00024: saving model to ./model\ 24-0.1570.hdf5
#
# Epoch 00025: saving model to ./model\ 25-0.1443.hdf5
#
# Epoch 00026: saving model to ./model\ 26-0.1401.hdf5
#
# Epoch 00027: saving model to ./model\ 27-0.1363.hdf5
#
# Epoch 00028: saving model to ./model\ 28-0.1321.hdf5
#
# Epoch 00029: saving model to ./model\ 29-0.1302.hdf5
#
# Epoch 00030: saving model to ./model\ 30-0.1257.hdf5
#
# Epoch 00031: saving model to ./model\ 31-0.1215.hdf5
#
# Epoch 00032: saving model to ./model\ 32-0.1251.hdf5
#
# Epoch 00033: saving model to ./model\ 33-0.1165.hdf5
#
# Epoch 00034: saving model to ./model\ 34-0.1121.hdf5
#
# Epoch 00035: saving model to ./model\ 35-0.1274.hdf5
#
# Epoch 00036: saving model to ./model\ 36-0.1156.hdf5
#
# Epoch 00037: saving model to ./model\ 37-0.1053.hdf5
#
# Epoch 00038: saving model to ./model\ 38-0.1026.hdf5
#
# Epoch 00039: saving model to ./model\ 39-0.1012.hdf5
#
# Epoch 00040: saving model to ./model\ 40-0.0998.hdf5
#
# Epoch 00041: saving model to ./model\ 41-0.1223.hdf5
#
# Epoch 00042: saving model to ./model\ 42-0.0990.hdf5
#
# Epoch 00043: saving model to ./model\ 43-0.0987.hdf5
#
# Epoch 00044: saving model to ./model\ 44-0.0927.hdf5
#
# Epoch 00045: saving model to ./model\ 45-0.0909.hdf5
#
# Epoch 00046: saving model to ./model\ 46-0.0901.hdf5
#
# Epoch 00047: saving model to ./model\ 47-0.0885.hdf5
#
# Epoch 00048: saving model to ./model\ 48-0.0880.hdf5
#
# Epoch 00049: saving model to ./model\ 49-0.0962.hdf5
#
# Epoch 00050: saving model to ./model\ 50-0.0852.hdf5
#
# Epoch 00051: saving model to ./model\ 51-0.0879.hdf5
#
# Epoch 00052: saving model to ./model\ 52-0.0843.hdf5
#
# Epoch 00053: saving model to ./model\ 53-0.0937.hdf5
#
# Epoch 00054: saving model to ./model\ 54-0.0813.hdf5
#
# Epoch 00055: saving model to ./model\ 55-0.0826.hdf5
#
# Epoch 00056: saving model to ./model\ 56-0.0791.hdf5
#
# Epoch 00057: saving model to ./model\ 57-0.0797.hdf5
#
# Epoch 00058: saving model to ./model\ 58-0.0806.hdf5
#
# Epoch 00059: saving model to ./model\ 59-0.0774.hdf5
#
# Epoch 00060: saving model to ./model\ 60-0.0875.hdf5
#
# Epoch 00061: saving model to ./model\ 61-0.0773.hdf5
#
# Epoch 00062: saving model to ./model\ 62-0.0735.hdf5
#
# Epoch 00063: saving model to ./model\ 63-0.0807.hdf5
#
# Epoch 00064: saving model to ./model\ 64-0.0759.hdf5
#
# Epoch 00065: saving model to ./model\ 65-0.0738.hdf5
#
# Epoch 00066: saving model to ./model\ 66-0.0776.hdf5
#
# Epoch 00067: saving model to ./model\ 67-0.0797.hdf5
#
# Epoch 00068: saving model to ./model\ 68-0.0698.hdf5
#
# Epoch 00069: saving model to ./model\ 69-0.0701.hdf5
#
# Epoch 00070: saving model to ./model\ 70-0.0693.hdf5
#
# Epoch 00071: saving model to ./model\ 71-0.0705.hdf5
#
# Epoch 00072: saving model to ./model\ 72-0.0733.hdf5
#
# Epoch 00073: saving model to ./model\ 73-0.0773.hdf5
#
# Epoch 00074: saving model to ./model\ 74-0.0801.hdf5
#
# Epoch 00075: saving model to ./model\ 75-0.0666.hdf5
#
# Epoch 00076: saving model to ./model\ 76-0.0674.hdf5
#
# Epoch 00077: saving model to ./model\ 77-0.0703.hdf5
#
# Epoch 00078: saving model to ./model\ 78-0.0657.hdf5
#
# Epoch 00079: saving model to ./model\ 79-0.0697.hdf5
#
# Epoch 00080: saving model to ./model\ 80-0.0691.hdf5
#
# Epoch 00081: saving model to ./model\ 81-0.0729.hdf5
#
# Epoch 00082: saving model to ./model\ 82-0.0690.hdf5
#
# Epoch 00083: saving model to ./model\ 83-0.0693.hdf5
#
# Epoch 00084: saving model to ./model\ 84-0.0638.hdf5
#
# Epoch 00085: saving model to ./model\ 85-0.0634.hdf5
#
# Epoch 00086: saving model to ./model\ 86-0.0676.hdf5
#
# Epoch 00087: saving model to ./model\ 87-0.0623.hdf5
#
# Epoch 00088: saving model to ./model\ 88-0.0640.hdf5
#
# Epoch 00089: saving model to ./model\ 89-0.0646.hdf5
#
# Epoch 00090: saving model to ./model\ 90-0.0640.hdf5
#
# Epoch 00091: saving model to ./model\ 91-0.0619.hdf5
#
# Epoch 00092: saving model to ./model\ 92-0.0648.hdf5
#
# Epoch 00093: saving model to ./model\ 93-0.0627.hdf5
#
# Epoch 00094: saving model to ./model\ 94-0.0698.hdf5
#
# Epoch 00095: saving model to ./model\ 95-0.0608.hdf5
#
# Epoch 00096: saving model to ./model\ 96-0.0613.hdf5
#
# Epoch 00097: saving model to ./model\ 97-0.0614.hdf5
#
# Epoch 00098: saving model to ./model\ 98-0.0711.hdf5
#
# Epoch 00099: saving model to ./model\ 99-0.0688.hdf5
#
# Epoch 00100: saving model to ./model\ 100-0.0841.hdf5
#
# Epoch 00101: saving model to ./model\ 101-0.0624.hdf5
#
# Epoch 00102: saving model to ./model\ 102-0.0752.hdf5
#
# Epoch 00103: saving model to ./model\ 103-0.0594.hdf5
#
# Epoch 00104: saving model to ./model\ 104-0.0606.hdf5
#
# Epoch 00105: saving model to ./model\ 105-0.0598.hdf5
#
# Epoch 00106: saving model to ./model\ 106-0.0598.hdf5
#
# Epoch 00107: saving model to ./model\ 107-0.0606.hdf5
#
# Epoch 00108: saving model to ./model\ 108-0.0590.hdf5
#
# Epoch 00109: saving model to ./model\ 109-0.0775.hdf5
#
# Epoch 00110: saving model to ./model\ 110-0.0585.hdf5
#
# Epoch 00111: saving model to ./model\ 111-0.0596.hdf5
#
# Epoch 00112: saving model to ./model\ 112-0.0582.hdf5
#
# Epoch 00113: saving model to ./model\ 113-0.0597.hdf5
#
# Epoch 00114: saving model to ./model\ 114-0.0614.hdf5
#
# Epoch 00115: saving model to ./model\ 115-0.0588.hdf5
#
# Epoch 00116: saving model to ./model\ 116-0.0707.hdf5
#
# Epoch 00117: saving model to ./model\ 117-0.0573.hdf5
#
# Epoch 00118: saving model to ./model\ 118-0.0635.hdf5
#
# Epoch 00119: saving model to ./model\ 119-0.0576.hdf5
#
# Epoch 00120: saving model to ./model\ 120-0.0580.hdf5
#
# Epoch 00121: saving model to ./model\ 121-0.0598.hdf5
#
# Epoch 00122: saving model to ./model\ 122-0.0581.hdf5
#
# Epoch 00123: saving model to ./model\ 123-0.0562.hdf5
#
# Epoch 00124: saving model to ./model\ 124-0.0748.hdf5
#
# Epoch 00125: saving model to ./model\ 125-0.0584.hdf5
#
# Epoch 00126: saving model to ./model\ 126-0.0562.hdf5
#
# Epoch 00127: saving model to ./model\ 127-0.0598.hdf5
#
# Epoch 00128: saving model to ./model\ 128-0.0566.hdf5
#
# Epoch 00129: saving model to ./model\ 129-0.0658.hdf5
#
# Epoch 00130: saving model to ./model\ 130-0.0583.hdf5
#
# Epoch 00131: saving model to ./model\ 131-0.0584.hdf5
#
# Epoch 00132: saving model to ./model\ 132-0.0705.hdf5
#
# Epoch 00133: saving model to ./model\ 133-0.0567.hdf5
#
# Epoch 00134: saving model to ./model\ 134-0.0608.hdf5
#
# Epoch 00135: saving model to ./model\ 135-0.0598.hdf5
#
# Epoch 00136: saving model to ./model\ 136-0.0553.hdf5
#
# Epoch 00137: saving model to ./model\ 137-0.0569.hdf5
#
# Epoch 00138: saving model to ./model\ 138-0.0590.hdf5
#
# Epoch 00139: saving model to ./model\ 139-0.0597.hdf5
#
# Epoch 00140: saving model to ./model\ 140-0.0551.hdf5
#
# Epoch 00141: saving model to ./model\ 141-0.0689.hdf5
#
# Epoch 00142: saving model to ./model\ 142-0.0675.hdf5
#
# Epoch 00143: saving model to ./model\ 143-0.0549.hdf5
#
# Epoch 00144: saving model to ./model\ 144-0.0665.hdf5
#
# Epoch 00145: saving model to ./model\ 145-0.0547.hdf5
#
# Epoch 00146: saving model to ./model\ 146-0.0555.hdf5
#
# Epoch 00147: saving model to ./model\ 147-0.0574.hdf5
#
# Epoch 00148: saving model to ./model\ 148-0.0562.hdf5
#
# Epoch 00149: saving model to ./model\ 149-0.0606.hdf5
#
# Epoch 00150: saving model to ./model\ 150-0.0539.hdf5
#
# Epoch 00151: saving model to ./model\ 151-0.0545.hdf5
#
# Epoch 00152: saving model to ./model\ 152-0.0597.hdf5
#
# Epoch 00153: saving model to ./model\ 153-0.0539.hdf5
#
# Epoch 00154: saving model to ./model\ 154-0.0555.hdf5
#
# Epoch 00155: saving model to ./model\ 155-0.0569.hdf5
#
# Epoch 00156: saving model to ./model\ 156-0.0632.hdf5
#
# Epoch 00157: saving model to ./model\ 157-0.0555.hdf5
#
# Epoch 00158: saving model to ./model\ 158-0.0547.hdf5
#
# Epoch 00159: saving model to ./model\ 159-0.0598.hdf5
#
# Epoch 00160: saving model to ./model\ 160-0.0559.hdf5
#
# Epoch 00161: saving model to ./model\ 161-0.0600.hdf5
#
# Epoch 00162: saving model to ./model\ 162-0.0580.hdf5
#
# Epoch 00163: saving model to ./model\ 163-0.0578.hdf5
#
# Epoch 00164: saving model to ./model\ 164-0.0585.hdf5
#
# Epoch 00165: saving model to ./model\ 165-0.0582.hdf5
#
# Epoch 00166: saving model to ./model\ 166-0.0583.hdf5
#
# Epoch 00167: saving model to ./model\ 167-0.0564.hdf5
#
# Epoch 00168: saving model to ./model\ 168-0.0585.hdf5
#
# Epoch 00169: saving model to ./model\ 169-0.0582.hdf5
#
# Epoch 00170: saving model to ./model\ 170-0.0575.hdf5
#
# Epoch 00171: saving model to ./model\ 171-0.0557.hdf5
#
# Epoch 00172: saving model to ./model\ 172-0.0553.hdf5
#
# Epoch 00173: saving model to ./model\ 173-0.0612.hdf5
#
# Epoch 00174: saving model to ./model\ 174-0.0585.hdf5
#
# Epoch 00175: saving model to ./model\ 175-0.0543.hdf5
#
# Epoch 00176: saving model to ./model\ 176-0.0594.hdf5
#
# Epoch 00177: saving model to ./model\ 177-0.0631.hdf5
#
# Epoch 00178: saving model to ./model\ 178-0.0553.hdf5
#
# Epoch 00179: saving model to ./model\ 179-0.0656.hdf5
#
# Epoch 00180: saving model to ./model\ 180-0.0870.hdf5
#
# Epoch 00181: saving model to ./model\ 181-0.0529.hdf5
#
# Epoch 00182: saving model to ./model\ 182-0.0543.hdf5
#
# Epoch 00183: saving model to ./model\ 183-0.0538.hdf5
#
# Epoch 00184: saving model to ./model\ 184-0.0542.hdf5
#
# Epoch 00185: saving model to ./model\ 185-0.0638.hdf5
#
# Epoch 00186: saving model to ./model\ 186-0.0547.hdf5
#
# Epoch 00187: saving model to ./model\ 187-0.0544.hdf5
#
# Epoch 00188: saving model to ./model\ 188-0.0661.hdf5
#
# Epoch 00189: saving model to ./model\ 189-0.0636.hdf5
#
# Epoch 00190: saving model to ./model\ 190-0.0556.hdf5
#
# Epoch 00191: saving model to ./model\ 191-0.0577.hdf5
#
# Epoch 00192: saving model to ./model\ 192-0.0565.hdf5
#
# Epoch 00193: saving model to ./model\ 193-0.0611.hdf5
#
# Epoch 00194: saving model to ./model\ 194-0.0734.hdf5
#
# Epoch 00195: saving model to ./model\ 195-0.0583.hdf5
#
# Epoch 00196: saving model to ./model\ 196-0.0759.hdf5
#
# Epoch 00197: saving model to ./model\ 197-0.0547.hdf5
#
# Epoch 00198: saving model to ./model\ 198-0.0561.hdf5
#
# Epoch 00199: saving model to ./model\ 199-0.0630.hdf5
#
# Epoch 00200: saving model to ./model\ 200-0.0649.hdf5
