# %% [markdown]
# ## 신경망(lecture/03.신경망.pdf)
#
# Dendrite : 수상돌기
#
# Axon : 축삭돌기
#
# 신경세포는 Synapse를 통해 어떤 신호를 받아서 아직 알수없는 로직에 의해 (입력) 증폭하거나(출력) 차단해버린다.
#
# 신경 모델은 이 기능을 차용해서 인공뉴런으로 모델화하였다.
# 여기서 그 알수없는 로직이란 모델에서는 Activation func, 활성함수이다.

# %%
import numpy as np 
import matplotlib.pyplot as plt

X1 = np.arange(-1.0, 1.0, 0.2)
X2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

w_x1 = 2.5
w_x2 = 3.0

bias =0.1

for i in range(10):
    for j in range(10):
        
        u=X1[i]*w_x1 + X2[j]*w_x2 + bias
        
        y=1/(1+np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, 'gray', vmin=0.0, vmax=1.0)
plt.colorbar()
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# x1, x2 값
X1 = np.arange(-1.0, 1.0, 0.2) # 원소 수는 10개
X2 = np.arange(-1.0, 1.0, 0.2)
# 출력값을 저장할 10x10 그리드
Z = np.zeros((10,10))
# x, y 값의 입력 가중치
W = np.array([2.5,3.0])
# 편향
bias = np.array([0.1])
# 그리드맵의 각 그리드별 뉴런의 연산
for i in range(10):
    for j in range(10):
        # 입력과 가중치 곱의 합 + 편향
        list1 = [X1[i], X2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias 
        # 그리드맵에 출력 값 저장
        y = 1/(1+np.exp(-u)) # 시그모이드 함수
        Z[j][i] = y
        # 그리드맵 표시
plt.imshow(Z, "gray", vmin = 0.0, vmax = 1.0)
plt.colorbar() 
plt.show()

# %%
np.array(list1)
# Out:
# array([0.8, 0.8])

# %%
import numpy as np
import matplotlib.pyplot as plt
# x1, x2 값
X1 = np.arange(-1.0, 1.0, 0.2) # 원소 수는 10개
X2 = np.arange(-1.0, 1.0, 0.2)
# 출력값을 저장할 10x10 그리드
Z = np.zeros((10,10))
# x, y 값의 입력 가중치
W = np.array([0,4.0])
# 편향
bias = np.array([0.1])
# 그리드맵의 각 그리드별 뉴런의 연산
for i in range(10):
    for j in range(10):
        # 입력과 가중치 곱의 합 + 편향
        list1 = [X1[i], X2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias 
        # 그리드맵에 출력 값 저장
        y = 1/(1+np.exp(-u)) # 시그모이드 함수
        Z[j][i] = y
        # 그리드맵 표시
plt.imshow(Z, "gray", vmin = 0.0, vmax = 1.0)
plt.colorbar() 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# x1, x2 값
X1 = np.arange(-1.0, 1.0, 0.2) # 원소 수는 10개
X2 = np.arange(-1.0, 1.0, 0.2)
# 출력값을 저장할 10x10 그리드
Z = np.zeros((10,10))
# x, y 값의 입력 가중치
W = np.array([-2.5, -3.0])
# 편향
bias = np.array([5])
# 그리드맵의 각 그리드별 뉴런의 연산
for i in range(10):
    for j in range(10):
        # 입력과 가중치 곱의 합 + 편향
        list1 = [X1[i], X2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias 
        # 그리드맵에 출력 값 저장
        y = 1/(1+np.exp(-u)) # 시그모이드 함수
        Z[j][i] = y
        # 그리드맵 표시
plt.imshow(Z, "gray", vmin = 0.0, vmax = 1.0)
plt.colorbar() 
plt.show()

# %%
X1 = np.arange(-1.0, 1.0, 0.2) # 원소 수는 10개
X2 = np.arange(-1.0, 1.0, 0.2)
# 출력값을 저장할 10x10 그리드
Z = np.zeros((10,10))
# x, y 값의 입력 가중치
W = np.array([2.5, 0])
# 편향
bias = np.array([0.1])
# 그리드맵의 각 그리드별 뉴런의 연산
for i in range(10):
    for j in range(10):
        # 입력과 가중치 곱의 합 + 편향
        list1 = [X1[i], X2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias 
        # 그리드맵에 출력 값 저장
        y = 1/(1+np.exp(-u)) # 시그모이드 함수
        Z[j][i] = y
        # 그리드맵 표시
plt.imshow(Z, "gray", vmin = 0.0, vmax = 1.0)
plt.colorbar() 
plt.show()

# %%
X1 = np.arange(-1.0, 1.0, 0.2) # 원소 수는 10개
X2 = np.arange(-1.0, 1.0, 0.2)
# 출력값을 저장할 10x10 그리드
Z = np.zeros((10,10))
# x, y 값의 입력 가중치
W = np.array([3.0, -3.0])
# 편향
bias = np.array([5])
# 그리드맵의 각 그리드별 뉴런의 연산
for i in range(10):
    for j in range(10):
        # 입력과 가중치 곱의 합 + 편향
        list1 = [X1[i], X2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias 
        # 그리드맵에 출력 값 저장
        y = 1/(1+np.exp(-u)) # 시그모이드 함수
        Z[j][i] = y
        # 그리드맵 표시
plt.imshow(Z, "gray", vmin = 0.0, vmax = 1.0)
plt.colorbar() 
plt.show()

# %% [markdown]
# ## bias가 하는 역할은 활성함수로 다음뉴런으로 신호를 보내는 과정에서 증폭을 하느냐 아니면 억제를 하느냐 하는것이다. bias가 그 부분에서 활성함수를 통과하느냐 못하느냐에 대해 지대한 역할을 한다는것이다

# %% [markdown]
# ## 다중 신경망

# %%
X = np.arange(-1.0, 1.0, 0.2)
Y = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

w_im = np.array([[4.0, 4.0], [4.0,4.0]]) #im:input to middle
w_mo = np.array([[1.0], [-1.0]])#mo:middle to output

b_im = np.array([3.0, -3.0])
b_mo = np.array([0.1])

def middle_layer(x, w, b):
    u = np.dot(x, w) + b
    return 1 / (1+np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x, w) + b
    return u

for i in range(10):
    for j in range(10):
        inp = np.array([X[i], Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        Z[j][i] = out[0] ##값이 하나뿐이어도 넘파이 배열로 나오므로 0번이라 써준다.
        
        
plt.imshow(Z, 'gray', vmin=0.0, vmax=1.0)
plt.colorbar()
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.show()

# %% [markdown]
# ## 분류

# %%
X = np.arange(-1.0, 1.0, 0.1)
Y = np.arange(-1.0, 1.0, 0.1)

w_im = np.array([[1.0, 2.0], [2.0, 3.0]])
w_mo = np.array([[-1.0, 1.0], [1.0, -1.0]]) #출력 레이어가 2개이므로 2개임


b_im = np.array([0.3, -0.3])
b_mo = np.array([0.4, 0.1])

def middle_layer(x,w,b):
    u = np.dot(x,w) + b
    return 1/(1+np.exp(-u))


def output_layer(x,w,b):
    u = np.dot(x,w) + b
    return np.exp(u)/np.sum(np.exp(u))

x_1 = []
y_1 = []
x_2 = []
y_2 = []


for i in range(20):
    for j in range(20):
        
        inp = np.array([X[i],Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        if out[0] > out[1]:
            x_1.append(X[i])
            y_1.append(Y[j])
        else:
            x_2.append(X[i])
            y_2.append(Y[j])
            
plt.scatter(x_1, y_1, marker="+")
plt.scatter(x_2, y_2, marker="o")
plt.show()

# %% [markdown]
# 이런 모양을 바이너리 분류라고 한다.

# %%
X = np.arange(-1.0, 1.0, 0.1)
Y = np.arange(-1.0, 1.0, 0.1)

w_im = np.array([[1.0, 2.0], [2.0, 3.0]])
w_mo = np.array([[-1.0, 1.0], [1.0, -1.0]]) #출력 레이어가 2개이므로 2개임


b_im = np.array([0.3, -0.3])
b_mo = np.array([0.4, 0.1])

def middle_layer(x,w,b):
    u = np.dot(x,w) + b
    return 1/(1+np.exp(-u))


def output_layer(x,w,b):
    u = np.dot(x,w) + b
    return np.exp(u)/np.sum(np.exp(u)) #softmax

x_1 = []
y_1 = []
x_2 = []
y_2 = []


for i in range(20):
    for j in range(20):
        
        inp = np.array([X[i],Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        if out[0] > out[1]:
            x_1.append(X[i])
            y_1.append(Y[j])
        else:
            x_2.append(X[i])
            y_2.append(Y[j])
            
plt.scatter(x_1, y_1, marker="+")
plt.scatter(x_2, y_2, marker="o")
plt.show()

# %% [markdown]
# ## 학습
# 이전까지는 bias와 weight을 고정시켜놓고 했는데 실제로는 이걸 랜덤으로 준다했죠...
# 그래서 우리가 가지고 있는 정답과 많이 다를 텐데 아무튼 이것의 편차를 최소화 시키는 방향으로
# 학습을 시키겠다는것이죠.

# %% [markdown]
# ## 04.역전파(backward propagation)
#
# 순전파: forward propagation
#
# (lecture/04.역전파.pdf)
#
# 순전파로 얻은 출력값과 정답값의 오차를 역방향으로 전파해서 이 오차에 근거해 각 층의 가중치와 bias의 수정량을 계산한다.

# %%
정답: 클래스, 레이블, 타겟
훈련데이터/테스트데이터 + 정답 의 한세트를 하나의 샘플이라고 한다. 


(Generalization)
